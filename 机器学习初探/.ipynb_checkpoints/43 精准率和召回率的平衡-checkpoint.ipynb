# %% [markdown]
# # 43 精准率和召回率的平衡

# %%
import numpy as np

# %%
def f1_score(precision, recall):
    try:
        return 2 * precision * recall / (precision + recall)
    except:
        return 0.0

# %%
precision = 0.5
recall = 0.5
f1_score(precision, recall)
# Out:
# 0.5

# %%
precision = 0.1
recall = 0.9
f1_score(precision, recall)
# Out:
# 0.18000000000000002

# %%
precision = 0
recall = 1
f1_score(precision, recall)
# Out:
# 0.0

# %%
from sklearn import datasets

digits = datasets.load_digits()
X = digits.data
y = digits.target.copy()

y[digits.target==9] = 1
y[digits.target!=9] = 0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(multi_class='ovr')
log_reg.fit(X_train, y_train)
log_reg.score(X_test, y_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9755555555555555

# %%
y_predict = log_reg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_predict)
# Out:
# array([[403,   2],
#        [  9,  36]])

# %%
from sklearn.metrics import precision_score

precision_score(y_test, y_predict)
# Out:
# 0.9473684210526315

# %%
from sklearn.metrics import recall_score

recall_score(y_test, y_predict)
# Out:
# 0.8

# %%
from sklearn.metrics import f1_score

f1_score(y_test, y_predict)
# Out:
# 0.8674698795180723

# %%
log_reg.decision_function(X_test)
# Out:
# array([-22.0570024 , -33.02945221, -16.21337365, -80.37916457,
#        -48.2512217 , -24.54007155, -44.39162664, -25.04297753,
#         -0.97827441, -19.71744311, -66.25136228, -51.09608392,
#        -31.49351047, -46.05330124, -38.67884383, -29.80471697,
#        -37.58854824, -82.57573749, -37.81901955, -11.01168288,
#         -9.17438674, -85.13006737, -16.71616141, -46.23734901,
#         -5.32998065, -47.91759101, -11.66730724, -39.19615703,
#        -25.25295996, -14.36647694, -16.99785597, -28.91908441,
#        -34.33944728, -29.47616028,  -7.85814832,  -3.82089473,
#        -24.08175194, -22.16361374, -33.61230532, -23.14028644,
#        -26.91808024, -62.38942167, -38.8569952 , -66.77265807,
#        -20.1448809 , -17.47888203, -18.06801551, -22.22228112,
#        -29.62305645, -19.73169121,   1.49550074,   8.32081189,
#        -36.2932115 , -42.50737231, -25.90457533, -34.98962851,
#         -8.42015948, -50.04724525, -51.4821182 ,  19.88963243,
#         -8.91891299, -31.99348167, -11.66105743,  -0.4714411 ,
#        -49.16131936, -46.23818672, -25.05390908, -19.61351065,
#        -36.16655138,  -3.12535935,  -3.91417492, -19.06043063,
#        -21.03316204, -41.52260722, -12.00620117, -33.89283011,
#        -35.84807187, -30.60488416, -56.51647737, -18.45470297,
#          4.5154303 , -17.21607654, -76.65097761, -58.5452372 ,
#        -31.72104355, -29.90831914, -33.31902423,  -9.08753692,
#        -47.64446607, -66.15301025, -16.95631954, -22.24906935,
#        -11.48964509, -18.10555603, -68.65403633, -47.02580807,
#        -40.11863707, -35.50211259, -17.1976675 , -63.10286693,
#        -16.95452332, -55.10235322, -28.71261229, -68.81581622,
